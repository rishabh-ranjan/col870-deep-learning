# %%
from sklearn.metrics import classification_report
import torch
import torch.nn.functional as F
# torch.cuda.set_device(1)
import models, train, utils
from importlib import reload
reload(models)
reload(train)
reload(utils)
# Out:
# <module 'utils' from '/home/cse/btech/cs1180416/col870-deep-learning/A2/utils.py'>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
digits_X = torch.load('data/pt-cache/digits_X.pt', map_location='cpu')
digits_y = torch.load('data/pt-cache/digits_y.pt', map_location='cpu')

# %%
lenet = models.LeNet()

# %%
train.train_net(lenet, digits_X, digits_y, lr=1e-3, batch_size=256, n_epochs=1, device=device)
# Out:
# HBox(children=(HTML(value='epochs'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='batches'), FloatProgress(value=0.0, max=176.0), HTML(value='')))
# [2.196913242340088,
#  2.1778361797332764,
#  2.1748688220977783,
#  2.1667838096618652,
#  2.1480493545532227,
#  2.135467529296875,
#  2.119302272796631,
#  2.096593141555786,
#  2.058722972869873,
#  2.0264976024627686,
#  1.986886739730835,
#  1.924037218093872,
#  1.8492680788040161,
#  1.8188244104385376,
#  1.7617288827896118,
#  1.7244032621383667,
#  1.6650431156158447,
#  1.5584921836853027,
#  1.565038800239563,
#  1.4600801467895508,
#  1.3853559494018555,
#  1.3329789638519287,
#  1.2145720720291138,
#  1.0686143636703491,
#  0.9847652316093445,
#  0.8631787896156311,
#  0.7817122340202332,
#  0.7676392793655396,
#  0.6619187593460083,
#  0.6153554916381836,
#  0.5930219888687134,
#  0.5232308506965637,
#  0.43252208828926086,
#  0.4567660689353943,
#  0.34156399965286255,
#  0.24867413938045502,
#  0.2881815433502197,
#  0.28849029541015625,
#  0.25332802534103394,
#  0.2024412453174591,
#  0.2242010235786438,
#  0.18026646971702576,
#  0.13052411377429962,
#  0.12057659029960632,
#  0.09098726511001587,
#  0.1079031452536583,
#  0.10139211267232895,
#  0.12849298119544983,
#  0.09886243939399719,
#  0.05780954286456108,
#  0.14749650657176971,
#  0.07883087545633316,
#  0.0654025673866272,
#  0.08818569034337997,
#  0.04919876158237457,
#  0.0667608231306076,
#  0.05065575987100601,
#  0.03310246020555496,
#  0.05768884718418121,
#  0.10939489305019379,
#  0.05353426933288574,
#  0.07267030328512192,
#  0.04479295387864113,
#  0.02963382750749588,
#  0.044347912073135376,
#  0.07546412199735641,
#  0.045968931168317795,
#  0.0845746099948883,
#  0.010906958021223545,
#  0.027871854603290558,
#  0.05911055952310562,
#  0.06414544582366943,
#  0.052967868745326996,
#  0.06493151187896729,
#  0.03320363163948059,
#  0.03188017010688782,
#  0.038381412625312805,
#  0.031160689890384674,
#  0.026324909180402756,
#  0.036492593586444855,
#  0.026997126638889313,
#  0.00999127235263586,
#  0.010793033055961132,
#  0.022206764668226242,
#  0.012573210522532463,
#  0.04350920021533966,
#  0.027210956439375877,
#  0.0287497416138649,
#  0.018532395362854004,
#  0.016644081100821495,
#  0.04056588187813759,
#  0.018293777480721474,
#  0.01391920167952776,
#  0.0202067531645298,
#  0.01485997810959816,
#  0.017931632697582245,
#  0.026208138093352318,
#  0.015157091431319714,
#  0.032646987587213516,
#  0.012958145700395107,
#  0.032201774418354034,
#  0.014630138874053955,
#  0.009532278403639793,
#  0.010693349875509739,
#  0.012718625366687775,
#  0.015490850433707237,
#  0.0075101349502801895,
#  0.012693950906395912,
#  0.00978317391127348,
#  0.010235552676022053,
#  0.014233662746846676,
#  0.04882436245679855,
#  0.00858472753316164,
#  0.013886364176869392,
#  0.017139825969934464,
#  0.026086101308465004,
#  0.019839640706777573,
#  0.01858390122652054,
#  0.0062148189172148705,
#  0.07383942604064941,
#  0.005400327034294605,
#  0.011606558226048946,
#  0.011015267111361027,
#  0.006315981969237328,
#  0.0055129509419202805,
#  0.010478829964995384,
#  0.013246077112853527,
#  0.010265369899570942,
#  0.019051849842071533,
#  0.01174937840551138,
#  0.015744531527161598,
#  0.017408359795808792,
#  0.005325468257069588,
#  0.009175904095172882,
#  0.01443716324865818,
#  0.03682323545217514,
#  0.017554903402924538,
#  0.013534557074308395,
#  0.039914391934871674,
#  0.02914656512439251,
#  0.01047817524522543,
#  0.04365815967321396,
#  0.012624086812138557,
#  0.0027203187346458435,
#  0.01325051300227642,
#  0.045299772173166275,
#  0.013084754347801208,
#  0.028792357072234154,
#  0.008341627195477486,
#  0.012396332807838917,
#  0.025212973356246948,
#  0.018336547538638115,
#  0.010677073150873184,
#  0.005329272709786892,
#  0.004332714714109898,
#  0.01820369064807892,
#  0.002539323642849922,
#  0.004336346872150898,
#  0.014299076050519943,
#  0.00551588274538517,
#  0.0028561782091856003,
#  0.025623684749007225,
#  0.004782550036907196,
#  0.001698290929198265,
#  0.007421683520078659,
#  0.011953674256801605,
#  0.004273807629942894,
#  0.024016106501221657,
#  0.005409054458141327,
#  0.010738572105765343,
#  0.014808660373091698,
#  0.005506798624992371,
#  0.007923334836959839,
#  0.017340805381536484,
#  0.005816474556922913,
#  0.007216357160359621]

# %%
query_X = torch.load('data/pt-cache/query_X_split.pt', map_location='cpu')
query_y = torch.load('data/pt-cache/query_y.pt', map_location='cpu')

# %%
print(classification_report(query_y[:10000], lenet.predict(query_X[:10000].to(device)).detach().cpu()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      5004
#            1       0.94      0.93      0.93       626
#            2       0.87      0.94      0.90       647
#            3       0.87      0.93      0.90       629
#            4       0.98      0.86      0.92       624
#            5       0.85      0.89      0.87       628
#            6       0.86      0.91      0.88       601
#            7       0.81      0.92      0.86       616
#            8       0.82      0.99      0.90       625
#
#     accuracy                           0.93     10000
#    macro avg       0.89      0.92      0.90     10000
# weighted avg       0.93      0.93      0.93     10000

# %%
torch.save(lenet.state_dict(), 'data/pt-cache/lenet.pt')
